# %% [markdown]
# # **Εργασία 1**
#
# Παλινδρόμηση με νευρωνικά δίκτυα και το climate change dataset.

# %% [markdown]
# ## Φόρτωση και προεργασία
#
# Φόρτωση βιβλιοθηκών, φόρτωση και απεικόνιση δεδομένων

# %%
# Εισάγουμε όλες τις απαραίτητες βιβλιοθήκες
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
# Φορτώνουμε το αρχείο CSV με τη βιβλιοθήκη Pandas μόνο για λόγους απεικόνισης
dataframe = pd.read_csv('climate_change.csv')
print(dataframe.head(5))
print("Διαστάσεις:", dataframe.shape)
# Out:
#    Year  Month    MEI     CO2      CH4      N2O   CFC-11   CFC-12        TSI  \
# 0  1983      5  2.556  345.96  1638.59  303.677  191.324  350.113  1366.1024
# 1  1983      6  2.167  345.52  1633.71  303.746  192.057  351.848  1366.1208
# 2  1983      7  1.741  344.15  1633.22  303.795  192.818  353.725  1366.2850
# 3  1983      8  1.130  342.25  1631.35  303.839  193.602  355.633  1366.4202
# 4  1983      9  0.428  340.17  1648.40  303.901  194.392  357.465  1366.2335
#
#    Aerosols   Temp
# 0    0.0863  0.109
# 1    0.0794  0.118
# 2    0.0731  0.137
# 3    0.0673  0.176
# 4    0.0619  0.149
# Διαστάσεις: (308, 11)

# %% [markdown]
# ## Δημιουργία custom αντικειμένου Dataset
#
# Δημιουργούμε ένα αντικείμενο Dataset το οποίο θα τροφοδοτήσει τους dataloaders, και ένα αντικείμενο transform που θα τροποποιεί τα δεδομένα πριν διαβαστούν από τους loaders.
#
# Στο μέλλον το transform θα είναι πολύ σημαντικό για το data augmentation, αλλά για την ώρα το χρησιμοποιούμε για την κανονικοποίηση των δεδομένων.

# %%
class ClimateDataset(torch.utils.data.Dataset):
  def __init__(self, csv_file, transform=None, train=True):
    """
    Args:
      csv_file (string): Path to the csv file
      transform (callable, optional): Optional transform to be applied
          on each sample.
      train (bool): whether to create the training set or the test set
    """

    # Ορίζουμε το μέγεθος του training set
    train_set_size = 250

    # Φόρτωση του csv μέσω Pandas, διαγραφή στηλών που δε βοηθούν στην ανάλυση,
    # μετατροπή των Pandas Dataframes σε Numpy Arrays, που έχουν πιο βοηθητικές
    # ιδιότητες
    dataframe = pd.read_csv(csv_file)
    targets = np.array(dataframe[['Temp']]).astype('float32')
    data = np.array(dataframe.drop(columns=['Year','Month','Temp'])).astype('float32')

    # Διαχωρισμός των δεδομένων σε training και test set
    # Αυτή η γραμμή θα πρέπει στο μέλλον να αντικατασταθεί αν θέλουμε να κάνουμε 
    # πιο ρεαλιστική αξιολόγηση
    # Θέτουμε και το seed στο random state για λόγους επαναληψιμότητας
    train_data, test_data, train_targets, test_targets = train_test_split(data, 
                            targets, train_size=train_set_size, random_state=665)

    # Θέτουμε και αρχικοποιούμε το transform
    self.transform = transform
    # Προσοχή, το transform αρχικοποιείται με τις τιμές του training set, είτε
    # το Dataset αφορά το train είτε το test set.
    self.transform.fit(train_data, train_targets)

    # Αν μας έχει ζητηθεί να δημιουργηθεί train database, κρατάμε τα train data.
    # Αλλιώς κρατάμε τα test data. 
    if train==True:
      self.data = train_data
      self.targets = train_targets
    else:
      self.data = test_data
      self.targets = test_targets
    # Η αρχικοποίηση τελειώνει εδώ

  # Ή __len__ ενός αντικειμένου Dataset οφείλει να επιστρέφει το πλήθος των
  # αντικειμένων του.
  def __len__(self):
    return len(self.targets)

  # Η __getitem__ ενός αντικειμένου Dataset παίρνει ως παράμετρο ένα index και 
  # επιστρέφει το αντίστοιχο αντικείμενο. Τη χρησιμοποιεί ο DataLoader για να 
  # αντλεί minibatches.
  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()
    item_data = self.data[idx,:]
    item_target = self.targets[idx,:]
    
    # Αν έχουμε ορίσει transform, το εφαρμόζουμε στο αντικείμενο πριν το 
    # επιστρέψουμε. Όταν καλώ το transform με το όνομά του, στην πραγματικότητα
    # καλείται η transform.__call__() (βλ. παρακάτω)
    if self.transform:
      item_data, item_target = self.transform(item_data, item_target)
    return item_data, item_target


# Η κλάση αυτή θα παίξει το ρόλο του Transform. Θα αφαιρεί την ελάχιστη τιμή
# από κάθε στήλη των δεδομένων και θα διαιρεί με το φάσμα της, ώστε να κανονικοποιεί
# τις τιμές όλων των μεταβλητών (και των στόχων) στο [0,1]
class MinMaxScaler():

  # H fit αρχικοποιείται με τα training data, και υπολογίζει τις ελάχιστες και 
  # μέγιστες τιμές. Τα αντικείμενα είναι numpy arrays, οπότε έχουν ενσωματωμένη
  # τη συνάρτηση min και max 
  def fit(self, data, targets):
    self.data_min = data.min(0, keepdims=True)
    self.target_min = targets.min(0, keepdims=True)
    self.data_max = data.max(0, keepdims=True)
    self.target_max = targets.max(0, keepdims=True)
    return self

  # Όταν καλείται η transform.__call__(), δέχεται ένα αντικείμενο (data και target)
  # και το επιστρέφει μετασχηματισμένο -εν προκειμένω κανονικοποιημένο
  def __call__(self, data, target):
    data = (data - self.data_min)/(self.data_max-self.data_min)
    target = (target - self.target_min)/(self.target_max-self.target_min)
    return data, target

  # Θα εκπαιδεύσουμε ένα σύστημα να μαθαίνει τα κανονικοποιημένα targets. Για
  # εφαρμογή στον πραγματικό κόσμο, θα χρειαστεί να μπορούμε να μετασχηματίζουμε
  # τα outputs του συστήματος πίσω στο αρχικό φάσμα τιμών του
  def inverse_transform(self, data, target):
    data=data * (self.data_max-self.data_min) + self.data_min
    target = target * (self.target_max-self.target_min) + self.target_min
    return data, target

# %% [markdown]
# ## Δημιουργία DataLoaders
#
# Δημιουργούμε dataloaders για το training set και για το test set.

# %%
# To batch size είναι αρκετά μεγάλο ώστε να χωράει όλα τα training data και όλα 
# τα test data σε ένα loop (πρακτικά εφαρμόζουμε Batch Gradient Descent, κάθε
# Batch είναι ένα Epoch) 
# (αν το batch size είναι μεγαλύτερο από τα διαθέσιμα δεδομένα, η pytorch 
# δημιουργεί ένα batch με τα διαθέσιμα δεδομένα)
batch_size = 500
transform=MinMaxScaler()

train_dataset = ClimateDataset(csv_file='climate_change.csv', train=True, transform=transform)
test_dataset = ClimateDataset(csv_file='climate_change.csv', train=False, transform=transform)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# ## Αρχιτεκτονική δικτύου
#
# Ορίζουμε ένα απλό δίκτυο με έναν νευρώνα για γραμμική παλινδρόμηση

# %%
# Κώδικας ορισμού του δικτύου
class NeuralNetwork1(nn.Module):
  def __init__(self):
      # Τρέχω την init της κλάσης-γονιού
      super(NeuralNetwork1, self).__init__()
      
      # Δημιουργώ μια μέθοδο Flatten που θα μετατρέπει το Tensor εισόδου σε
      # μονοδιάστατο
      self.flatten = nn.Flatten()

      # Η κλάση Sequential() είναι ένα container μέσα στο οποίο βάζουμε τα
      # Module() που θα χτίζουν τα layers του δικτύου 
      self.network_architecture = nn.Sequential(
          nn.Linear(8,1)
      ) 

  # Η μέθοδος forward απλώς μετατρέπει τα inputs σε διάνυσμα και τα περνάει
  # από τη network_architecture που δημιουργήσαμε
  def forward(self, x):
      x = self.flatten(x)
      logits = self.network_architecture(x)
      return logits

# %% [markdown]
# Μετα την προέργασια απο την κλαση το input χ του δικτύου αποτελείται απο 250 μεταβλητες και 8 κατηγοριες

# %% [markdown]
# ## Training και Test Loop
#
# Γράφουμε τον κώδικα του training loop και του test loop

# %%
def train_loop(dataloader, model, loss_fn, optimizer, display):
    #για το μεγεθος
    size = len(dataloader.dataset)

    for batch, (X, y) in enumerate(dataloader):

      pred = model(X)
      y = np.reshape(y,(250,1))
      loss = loss_fn(pred, y)

      # Backpropagation
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if np.mod(display , 100 ) == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss  = 0

    with torch.no_grad():
      for X, y in dataloader:
          pred = model(X)
          y = np.reshape(y,(58,1))
          test_loss += loss_fn(pred, y).item()
              
    test_loss /= num_batches
    r2 = r2_score(y, pred) 
    print(f"Test Error: \n r2_scoere: {(100*r2):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# ## Ορισμός υπερπαραμέτρων και εκπαίδευση δικτύου
#
# Κώδικας εκτέλεσης και αξιολόγησης του δικτύου

# %%
# Το manual_seed καθορίζει την τυχαία αρχικοποίηση των βαρών/παραμέτρων του δικτύου
# Πρόκειται απλώς για ένα σταθερό seed στο random number generator της pytorch.
torch.manual_seed(50)
model = NeuralNetwork1()
learning_rate = 0.001
# Ορίζουμε τη Loss Function
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Κώδικας εκπαίδευσης εδώ:

for t in range(3000):
    print(f"Epoch {t+1}\n-------------------------------")
    display = t
    train_loop(train_dataloader, model, loss_fn, optimizer, display)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 2003
# -------------------------------
# Test Error:
#  r2_scoere: 60.9%, Avg loss: 0.008209
#
# Epoch 2004
# -------------------------------
# Test Error:
#  r2_scoere: 60.9%, Avg loss: 0.008206
#
# Epoch 2005
# -------------------------------
# Test Error:
#  r2_scoere: 60.9%, Avg loss: 0.008204
#
# Epoch 2006
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008201
#
# Epoch 2007
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008198
#
# Epoch 2008
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008195
#
# Epoch 2009
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008193
#
# Epoch 2010
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008190
#
# Epoch 2011
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008187
#
# Epoch 2012
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008185
#
# Epoch 2013
# -------------------------------
# Test Error:
#  r2_scoere: 61.0%, Avg loss: 0.008182
#
# Epoch 2014
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008179
#
# Epoch 2015
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008176
#
# Epoch 2016
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008174
#
# Epoch 2017
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008171
#
# Epoch 2018
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008168
#
# Epoch 2019
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008166
#
# Epoch 2020
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008163
#
# Epoch 2021
# -------------------------------
# Test Error:
#  r2_scoere: 61.1%, Avg loss: 0.008160
#
# Epoch 2022
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008158
#
# Epoch 2023
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008155
#
# Epoch 2024
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008152
#
# Epoch 2025
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008149
#
# Epoch 2026
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008147
#
# Epoch 2027
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008144
#
# Epoch 2028
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008141
#
# Epoch 2029
# -------------------------------
# Test Error:
#  r2_scoere: 61.2%, Avg loss: 0.008139
#
# Epoch 2030
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008136
#
# Epoch 2031
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008133
#
# Epoch 2032
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008131
#
# Epoch 2033
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008128
#
# Epoch 2034
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008125
#
# Epoch 2035
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008123
#
# Epoch 2036
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008120
#
# Epoch 2037
# -------------------------------
# Test Error:
#  r2_scoere: 61.3%, Avg loss: 0.008117
#
# Epoch 2038
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008115
#
# Epoch 2039
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008112
#
# Epoch 2040
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008109
#
# Epoch 2041
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008107
#
# Epoch 2042
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008104
#
# Epoch 2043
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008102
#
# Epoch 2044
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008099
#
# Epoch 2045
# -------------------------------
# Test Error:
#  r2_scoere: 61.4%, Avg loss: 0.008096
#
# Epoch 2046
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008094
#
# Epoch 2047
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008091
#
# Epoch 2048
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008088
#
# Epoch 2049
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008086
#
# Epoch 2050
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008083
#
# Epoch 2051
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008080
#
# Epoch 2052
# -------------------------------
# Test Error:
#  r2_scoere: 61.5%, Avg loss: 0.008078
#
# Epoch 2053
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008075
#
# Epoch 2054
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008073
#
# Epoch 2055
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008070
#
# Epoch 2056
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008067
#
# Epoch 2057
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008065
#
# Epoch 2058
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008062
#
# Epoch 2059
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008060
#
# Epoch 2060
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008057
#
# Epoch 2061
# -------------------------------
# Test Error:
#  r2_scoere: 61.6%, Avg loss: 0.008054
#
# Epoch 2062
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008052
#
# Epoch 2063
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008049
#
# Epoch 2064
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008047
#
# Epoch 2065
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008044
#
# Epoch 2066
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008041
#
# Epoch 2067
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008039
#
# Epoch 2068
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008036
#
# Epoch 2069
# -------------------------------
# Test Error:
#  r2_scoere: 61.7%, Avg loss: 0.008034
#
# Epoch 2070
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008031
#
# Epoch 2071
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008028
#
# Epoch 2072
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008026
#
# Epoch 2073
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008023
#
# Epoch 2074
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008021
#
# Epoch 2075
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008018
#
# Epoch 2076
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008016
#
# Epoch 2077
# -------------------------------
# Test Error:
#  r2_scoere: 61.8%, Avg loss: 0.008013
#
# Epoch 2078
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.008010
#
# Epoch 2079
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.008008
#
# Epoch 2080
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.008005
#
# Epoch 2081
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.008003
#
# Epoch 2082
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.008000
#
# Epoch 2083
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.007998
#
# Epoch 2084
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.007995
#
# Epoch 2085
# -------------------------------
# Test Error:
#  r2_scoere: 61.9%, Avg loss: 0.007993
#
# Epoch 2086
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007990
#
# Epoch 2087
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007988
#
# Epoch 2088
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007985
#
# Epoch 2089
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007982
#
# Epoch 2090
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007980
#
# Epoch 2091
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007977
#
# Epoch 2092
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007975
#
# Epoch 2093
# -------------------------------
# Test Error:
#  r2_scoere: 62.0%, Avg loss: 0.007972
#
# Epoch 2094
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007970
#
# Epoch 2095
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007967
#
# Epoch 2096
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007965
#
# Epoch 2097
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007962
#
# Epoch 2098
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007960
#
# Epoch 2099
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007957
#
# Epoch 2100
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007955
#
# Epoch 2101
# -------------------------------
# loss: 0.011039  [    0/  250]
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007952
#
# Epoch 2102
# -------------------------------
# Test Error:
#  r2_scoere: 62.1%, Avg loss: 0.007950
#
# Epoch 2103
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007947
#
# Epoch 2104
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007945
#
# Epoch 2105
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007942
#
# Epoch 2106
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007940
#
# Epoch 2107
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007937
#
# Epoch 2108
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007935
#
# Epoch 2109
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007932
#
# Epoch 2110
# -------------------------------
# Test Error:
#  r2_scoere: 62.2%, Avg loss: 0.007930
#
# Epoch 2111
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007927
#
# Epoch 2112
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007925
#
# Epoch 2113
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007922
#
# Epoch 2114
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007920
#
# Epoch 2115
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007917
#
# Epoch 2116
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007915
#
# Epoch 2117
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007912
#
# Epoch 2118
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007910
#
# Epoch 2119
# -------------------------------
# Test Error:
#  r2_scoere: 62.3%, Avg loss: 0.007907
#
# Epoch 2120
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007905
#
# Epoch 2121
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007902
#
# Epoch 2122
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007900
#
# Epoch 2123
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007897
#
# Epoch 2124
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007895
#
# Epoch 2125
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007893
#
# Epoch 2126
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007890
#
# Epoch 2127
# -------------------------------
# Test Error:
#  r2_scoere: 62.4%, Avg loss: 0.007888
#
# Epoch 2128
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007885
#
# Epoch 2129
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007883
#
# Epoch 2130
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007880
#
# Epoch 2131
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007878
#
# Epoch 2132
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007875
#
# Epoch 2133
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007873
#
# Epoch 2134
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007870
#
# Epoch 2135
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007868
#
# Epoch 2136
# -------------------------------
# Test Error:
#  r2_scoere: 62.5%, Avg loss: 0.007866
#
# Epoch 2137
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007863
#
# Epoch 2138
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007861
#
# Epoch 2139
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007858
#
# Epoch 2140
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007856
#
# Epoch 2141
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007853
#
# Epoch 2142
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007851
#
# Epoch 2143
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007849
#
# Epoch 2144
# -------------------------------
# Test Error:
#  r2_scoere: 62.6%, Avg loss: 0.007846
#
# Epoch 2145
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007844
#
# Epoch 2146
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007841
#
# Epoch 2147
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007839
#
# Epoch 2148
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007837
#
# Epoch 2149
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007834
#
# Epoch 2150
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007832
#
# Epoch 2151
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007829
#
# Epoch 2152
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007827
#
# Epoch 2153
# -------------------------------
# Test Error:
#  r2_scoere: 62.7%, Avg loss: 0.007825
#
# Epoch 2154
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007822
#
# Epoch 2155
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007820
#
# Epoch 2156
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007817
#
# Epoch 2157
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007815
#
# Epoch 2158
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007813
#
# Epoch 2159
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007810
#
# Epoch 2160
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007808
#
# Epoch 2161
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007805
#
# Epoch 2162
# -------------------------------
# Test Error:
#  r2_scoere: 62.8%, Avg loss: 0.007803
#
# Epoch 2163
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007801
#
# Epoch 2164
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007798
#
# Epoch 2165
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007796
#
# Epoch 2166
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007794
#
# Epoch 2167
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007791
#
# Epoch 2168
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007789
#
# Epoch 2169
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007787
#
# Epoch 2170
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007784
#
# Epoch 2171
# -------------------------------
# Test Error:
#  r2_scoere: 62.9%, Avg loss: 0.007782
#
# Epoch 2172
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007779
#
# Epoch 2173
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007777
#
# Epoch 2174
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007775
#
# Epoch 2175
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007772
#
# Epoch 2176
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007770
#
# Epoch 2177
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007768
#
# Epoch 2178
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007765
#
# Epoch 2179
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007763
#
# Epoch 2180
# -------------------------------
# Test Error:
#  r2_scoere: 63.0%, Avg loss: 0.007761
#
# Epoch 2181
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007758
#
# Epoch 2182
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007756
#
# Epoch 2183
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007754
#
# Epoch 2184
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007751
#
# Epoch 2185
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007749
#
# Epoch 2186
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007747
#
# Epoch 2187
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007744
#
# Epoch 2188
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007742
#
# Epoch 2189
# -------------------------------
# Test Error:
#  r2_scoere: 63.1%, Avg loss: 0.007740
#
# Epoch 2190
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007737
#
# Epoch 2191
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007735
#
# Epoch 2192
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007733
#
# Epoch 2193
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007731
#
# Epoch 2194
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007728
#
# Epoch 2195
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007726
#
# Epoch 2196
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007724
#
# Epoch 2197
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007721
#
# Epoch 2198
# -------------------------------
# Test Error:
#  r2_scoere: 63.2%, Avg loss: 0.007719
#
# Epoch 2199
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007717
#
# Epoch 2200
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007714
#
# Epoch 2201
# -------------------------------
# loss: 0.010821  [    0/  250]
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007712
#
# Epoch 2202
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007710
#
# Epoch 2203
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007708
#
# Epoch 2204
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007705
#
# Epoch 2205
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007703
#
# Epoch 2206
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007701
#
# Epoch 2207
# -------------------------------
# Test Error:
#  r2_scoere: 63.3%, Avg loss: 0.007698
#
# Epoch 2208
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007696
#
# Epoch 2209
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007694
#
# Epoch 2210
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007692
#
# Epoch 2211
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007689
#
# Epoch 2212
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007687
#
# Epoch 2213
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007685
#
# Epoch 2214
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007683
#
# Epoch 2215
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007680
#
# Epoch 2216
# -------------------------------
# Test Error:
#  r2_scoere: 63.4%, Avg loss: 0.007678
#
# Epoch 2217
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007676
#
# Epoch 2218
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007674
#
# Epoch 2219
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007671
#
# Epoch 2220
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007669
#
# Epoch 2221
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007667
#
# Epoch 2222
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007665
#
# Epoch 2223
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007662
#
# Epoch 2224
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007660
#
# Epoch 2225
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007658
#
# Epoch 2226
# -------------------------------
# Test Error:
#  r2_scoere: 63.5%, Avg loss: 0.007656
#
# Epoch 2227
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007653
#
# Epoch 2228
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007651
#
# Epoch 2229
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007649
#
# Epoch 2230
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007647
#
# Epoch 2231
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007644
#
# Epoch 2232
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007642
#
# Epoch 2233
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007640
#
# Epoch 2234
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007638
#
# Epoch 2235
# -------------------------------
# Test Error:
#  r2_scoere: 63.6%, Avg loss: 0.007636
#
# Epoch 2236
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007633
#
# Epoch 2237
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007631
#
# Epoch 2238
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007629
#
# Epoch 2239
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007627
#
# Epoch 2240
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007625
#
# Epoch 2241
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007622
#
# Epoch 2242
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007620
#
# Epoch 2243
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007618
#
# Epoch 2244
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007616
#
# Epoch 2245
# -------------------------------
# Test Error:
#  r2_scoere: 63.7%, Avg loss: 0.007614
#
# Epoch 2246
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007611
#
# Epoch 2247
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007609
#
# Epoch 2248
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007607
#
# Epoch 2249
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007605
#
# Epoch 2250
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007603
#
# Epoch 2251
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007600
#
# Epoch 2252
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007598
#
# Epoch 2253
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007596
#
# Epoch 2254
# -------------------------------
# Test Error:
#  r2_scoere: 63.8%, Avg loss: 0.007594
#
# Epoch 2255
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007592
#
# Epoch 2256
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007590
#
# Epoch 2257
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007587
#
# Epoch 2258
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007585
#
# Epoch 2259
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007583
#
# Epoch 2260
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007581
#
# Epoch 2261
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007579
#
# Epoch 2262
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007577
#
# Epoch 2263
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007574
#
# Epoch 2264
# -------------------------------
# Test Error:
#  r2_scoere: 63.9%, Avg loss: 0.007572
#
# Epoch 2265
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007570
#
# Epoch 2266
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007568
#
# Epoch 2267
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007566
#
# Epoch 2268
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007564
#
# Epoch 2269
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007562
#
# Epoch 2270
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007559
#
# Epoch 2271
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007557
#
# Epoch 2272
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007555
#
# Epoch 2273
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007553
#
# Epoch 2274
# -------------------------------
# Test Error:
#  r2_scoere: 64.0%, Avg loss: 0.007551
#
# Epoch 2275
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007549
#
# Epoch 2276
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007547
#
# Epoch 2277
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007545
#
# Epoch 2278
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007542
#
# Epoch 2279
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007540
#
# Epoch 2280
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007538
#
# Epoch 2281
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007536
#
# Epoch 2282
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007534
#
# Epoch 2283
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007532
#
# Epoch 2284
# -------------------------------
# Test Error:
#  r2_scoere: 64.1%, Avg loss: 0.007530
#
# Epoch 2285
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007528
#
# Epoch 2286
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007525
#
# Epoch 2287
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007523
#
# Epoch 2288
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007521
#
# Epoch 2289
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007519
#
# Epoch 2290
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007517
#
# Epoch 2291
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007515
#
# Epoch 2292
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007513
#
# Epoch 2293
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007511
#
# Epoch 2294
# -------------------------------
# Test Error:
#  r2_scoere: 64.2%, Avg loss: 0.007509
#
# Epoch 2295
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007507
#
# Epoch 2296
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007505
#
# Epoch 2297
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007502
#
# Epoch 2298
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007500
#
# Epoch 2299
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007498
#
# Epoch 2300
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007496
#
# Epoch 2301
# -------------------------------
# loss: 0.010624  [    0/  250]
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007494
#
# Epoch 2302
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007492
#
# Epoch 2303
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007490
#
# Epoch 2304
# -------------------------------
# Test Error:
#  r2_scoere: 64.3%, Avg loss: 0.007488
#
# Epoch 2305
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007486
#
# Epoch 2306
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007484
#
# Epoch 2307
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007482
#
# Epoch 2308
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007480
#
# Epoch 2309
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007478
#
# Epoch 2310
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007476
#
# Epoch 2311
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007474
#
# Epoch 2312
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007472
#
# Epoch 2313
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007469
#
# Epoch 2314
# -------------------------------
# Test Error:
#  r2_scoere: 64.4%, Avg loss: 0.007467
#
# Epoch 2315
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007465
#
# Epoch 2316
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007463
#
# Epoch 2317
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007461
#
# Epoch 2318
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007459
#
# Epoch 2319
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007457
#
# Epoch 2320
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007455
#
# Epoch 2321
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007453
#
# Epoch 2322
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007451
#
# Epoch 2323
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007449
#
# Epoch 2324
# -------------------------------
# Test Error:
#  r2_scoere: 64.5%, Avg loss: 0.007447
#
# Epoch 2325
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007445
#
# Epoch 2326
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007443
#
# Epoch 2327
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007441
#
# Epoch 2328
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007439
#
# Epoch 2329
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007437
#
# Epoch 2330
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007435
#
# Epoch 2331
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007433
#
# Epoch 2332
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007431
#
# Epoch 2333
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007429
#
# Epoch 2334
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007427
#
# Epoch 2335
# -------------------------------
# Test Error:
#  r2_scoere: 64.6%, Avg loss: 0.007425
#
# Epoch 2336
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007423
#
# Epoch 2337
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007421
#
# Epoch 2338
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007419
#
# Epoch 2339
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007417
#
# Epoch 2340
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007415
#
# Epoch 2341
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007413
#
# Epoch 2342
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007411
#
# Epoch 2343
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007409
#
# Epoch 2344
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007407
#
# Epoch 2345
# -------------------------------
# Test Error:
#  r2_scoere: 64.7%, Avg loss: 0.007405
#
# Epoch 2346
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007403
#
# Epoch 2347
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007401
#
# Epoch 2348
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007399
#
# Epoch 2349
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007397
#
# Epoch 2350
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007395
#
# Epoch 2351
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007393
#
# Epoch 2352
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007391
#
# Epoch 2353
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007389
#
# Epoch 2354
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007387
#
# Epoch 2355
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007385
#
# Epoch 2356
# -------------------------------
# Test Error:
#  r2_scoere: 64.8%, Avg loss: 0.007383
#
# Epoch 2357
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007381
#
# Epoch 2358
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007379
#
# Epoch 2359
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007377
#
# Epoch 2360
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007376
#
# Epoch 2361
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007374
#
# Epoch 2362
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007372
#
# Epoch 2363
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007370
#
# Epoch 2364
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007368
#
# Epoch 2365
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007366
#
# Epoch 2366
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007364
#
# Epoch 2367
# -------------------------------
# Test Error:
#  r2_scoere: 64.9%, Avg loss: 0.007362
#
# Epoch 2368
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007360
#
# Epoch 2369
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007358
#
# Epoch 2370
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007356
#
# Epoch 2371
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007354
#
# Epoch 2372
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007352
#
# Epoch 2373
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007350
#
# Epoch 2374
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007348
#
# Epoch 2375
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007347
#
# Epoch 2376
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007345
#
# Epoch 2377
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007343
#
# Epoch 2378
# -------------------------------
# Test Error:
#  r2_scoere: 65.0%, Avg loss: 0.007341
#
# Epoch 2379
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007339
#
# Epoch 2380
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007337
#
# Epoch 2381
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007335
#
# Epoch 2382
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007333
#
# Epoch 2383
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007331
#
# Epoch 2384
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007329
#
# Epoch 2385
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007327
#
# Epoch 2386
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007326
#
# Epoch 2387
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007324
#
# Epoch 2388
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007322
#
# Epoch 2389
# -------------------------------
# Test Error:
#  r2_scoere: 65.1%, Avg loss: 0.007320
#
# Epoch 2390
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007318
#
# Epoch 2391
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007316
#
# Epoch 2392
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007314
#
# Epoch 2393
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007312
#
# Epoch 2394
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007310
#
# Epoch 2395
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007309
#
# Epoch 2396
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007307
#
# Epoch 2397
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007305
#
# Epoch 2398
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007303
#
# Epoch 2399
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007301
#
# Epoch 2400
# -------------------------------
# Test Error:
#  r2_scoere: 65.2%, Avg loss: 0.007299
#
# Epoch 2401
# -------------------------------
# loss: 0.010448  [    0/  250]
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007297
#
# Epoch 2402
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007295
#
# Epoch 2403
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007294
#
# Epoch 2404
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007292
#
# Epoch 2405
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007290
#
# Epoch 2406
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007288
#
# Epoch 2407
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007286
#
# Epoch 2408
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007284
#
# Epoch 2409
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007282
#
# Epoch 2410
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007281
#
# Epoch 2411
# -------------------------------
# Test Error:
#  r2_scoere: 65.3%, Avg loss: 0.007279
#
# Epoch 2412
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007277
#
# Epoch 2413
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007275
#
# Epoch 2414
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007273
#
# Epoch 2415
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007271
#
# Epoch 2416
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007270
#
# Epoch 2417
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007268
#
# Epoch 2418
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007266
#
# Epoch 2419
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007264
#
# Epoch 2420
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007262
#
# Epoch 2421
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007260
#
# Epoch 2422
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007259
#
# Epoch 2423
# -------------------------------
# Test Error:
#  r2_scoere: 65.4%, Avg loss: 0.007257
#
# Epoch 2424
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007255
#
# Epoch 2425
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007253
#
# Epoch 2426
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007251
#
# Epoch 2427
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007249
#
# Epoch 2428
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007248
#
# Epoch 2429
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007246
#
# Epoch 2430
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007244
#
# Epoch 2431
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007242
#
# Epoch 2432
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007240
#
# Epoch 2433
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007239
#
# Epoch 2434
# -------------------------------
# Test Error:
#  r2_scoere: 65.5%, Avg loss: 0.007237
#
# Epoch 2435
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007235
#
# Epoch 2436
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007233
#
# Epoch 2437
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007231
#
# Epoch 2438
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007230
#
# Epoch 2439
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007228
#
# Epoch 2440
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007226
#
# Epoch 2441
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007224
#
# Epoch 2442
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007222
#
# Epoch 2443
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007221
#
# Epoch 2444
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007219
#
# Epoch 2445
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007217
#
# Epoch 2446
# -------------------------------
# Test Error:
#  r2_scoere: 65.6%, Avg loss: 0.007215
#
# Epoch 2447
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007214
#
# Epoch 2448
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007212
#
# Epoch 2449
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007210
#
# Epoch 2450
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007208
#
# Epoch 2451
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007206
#
# Epoch 2452
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007205
#
# Epoch 2453
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007203
#
# Epoch 2454
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007201
#
# Epoch 2455
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007199
#
# Epoch 2456
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007198
#
# Epoch 2457
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007196
#
# Epoch 2458
# -------------------------------
# Test Error:
#  r2_scoere: 65.7%, Avg loss: 0.007194
#
# Epoch 2459
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007192
#
# Epoch 2460
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007191
#
# Epoch 2461
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007189
#
# Epoch 2462
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007187
#
# Epoch 2463
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007185
#
# Epoch 2464
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007184
#
# Epoch 2465
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007182
#
# Epoch 2466
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007180
#
# Epoch 2467
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007178
#
# Epoch 2468
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007177
#
# Epoch 2469
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007175
#
# Epoch 2470
# -------------------------------
# Test Error:
#  r2_scoere: 65.8%, Avg loss: 0.007173
#
# Epoch 2471
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007172
#
# Epoch 2472
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007170
#
# Epoch 2473
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007168
#
# Epoch 2474
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007166
#
# Epoch 2475
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007165
#
# Epoch 2476
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007163
#
# Epoch 2477
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007161
#
# Epoch 2478
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007159
#
# Epoch 2479
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007158
#
# Epoch 2480
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007156
#
# Epoch 2481
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007154
#
# Epoch 2482
# -------------------------------
# Test Error:
#  r2_scoere: 65.9%, Avg loss: 0.007153
#
# Epoch 2483
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007151
#
# Epoch 2484
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007149
#
# Epoch 2485
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007147
#
# Epoch 2486
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007146
#
# Epoch 2487
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007144
#
# Epoch 2488
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007142
#
# Epoch 2489
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007141
#
# Epoch 2490
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007139
#
# Epoch 2491
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007137
#
# Epoch 2492
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007136
#
# Epoch 2493
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007134
#
# Epoch 2494
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007132
#
# Epoch 2495
# -------------------------------
# Test Error:
#  r2_scoere: 66.0%, Avg loss: 0.007131
#
# Epoch 2496
# -------------------------------
# Test Error:
#  r2_scoere: 66.1%, Avg loss: 0.007129
#
# Epoch 2497
# -------------------------------
# Test Error:
#  r2_scoere: 66.1%, Avg loss: 0.007127
#
# Epoch 2498
# -------------------------------
# Test Error:
#  r2_scoere: 66.1%, Avg loss: 0.007125
#
# Epoch 2499
# -------------------------------
# Test Error:
#  r2_scoere: 66.1%, Avg loss: 0.007124
#
# Epoch 2500
# -------------------------------
# Test Error:
#  r2_scoere: 66.1%, Avg loss: 0.007122
#
# Epoch 2501
# ...
#
# Epoch 2835
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006656
#
# Epoch 2836
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006655
#
# Epoch 2837
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006654
#
# Epoch 2838
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006653
#
# Epoch 2839
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006652
#
# Epoch 2840
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006651
#
# Epoch 2841
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006650
#
# Epoch 2842
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006649
#
# Epoch 2843
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006647
#
# Epoch 2844
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006646
#
# Epoch 2845
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006645
#
# Epoch 2846
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006644
#
# Epoch 2847
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006643
#
# Epoch 2848
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006642
#
# Epoch 2849
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006641
#
# Epoch 2850
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006640
#
# Epoch 2851
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006639
#
# Epoch 2852
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006637
#
# Epoch 2853
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006636
#
# Epoch 2854
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006635
#
# Epoch 2855
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006634
#
# Epoch 2856
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006633
#
# Epoch 2857
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006632
#
# Epoch 2858
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006631
#
# Epoch 2859
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006630
#
# Epoch 2860
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006629
#
# Epoch 2861
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006628
#
# Epoch 2862
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006626
#
# Epoch 2863
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006625
#
# Epoch 2864
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006624
#
# Epoch 2865
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006623
#
# Epoch 2866
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006622
#
# Epoch 2867
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006621
#
# Epoch 2868
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006620
#
# Epoch 2869
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006619
#
# Epoch 2870
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006618
#
# Epoch 2871
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006617
#
# Epoch 2872
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006616
#
# Epoch 2873
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006614
#
# Epoch 2874
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006613
#
# Epoch 2875
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006612
#
# Epoch 2876
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006611
#
# Epoch 2877
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006610
#
# Epoch 2878
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006609
#
# Epoch 2879
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006608
#
# Epoch 2880
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006607
#
# Epoch 2881
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006606
#
# Epoch 2882
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006605
#
# Epoch 2883
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006604
#
# Epoch 2884
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006603
#
# Epoch 2885
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006602
#
# Epoch 2886
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006601
#
# Epoch 2887
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006599
#
# Epoch 2888
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006598
#
# Epoch 2889
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006597
#
# Epoch 2890
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006596
#
# Epoch 2891
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006595
#
# Epoch 2892
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006594
#
# Epoch 2893
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006593
#
# Epoch 2894
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006592
#
# Epoch 2895
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006591
#
# Epoch 2896
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006590
#
# Epoch 2897
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006589
#
# Epoch 2898
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006588
#
# Epoch 2899
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006587
#
# Epoch 2900
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006586
#
# Epoch 2901
# -------------------------------
# loss: 0.009806  [    0/  250]
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006585
#
# Epoch 2902
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006584
#
# Epoch 2903
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006583
#
# Epoch 2904
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006582
#
# Epoch 2905
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006581
#
# Epoch 2906
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006580
#
# Epoch 2907
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2908
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006577
#
# Epoch 2909
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006576
#
# Epoch 2910
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006575
#
# Epoch 2911
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006574
#
# Epoch 2912
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006573
#
# Epoch 2913
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006572
#
# Epoch 2914
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006571
#
# Epoch 2915
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006570
#
# Epoch 2916
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006569
#
# Epoch 2917
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006568
#
# Epoch 2918
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006567
#
# Epoch 2919
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006566
#
# Epoch 2920
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006565
#
# Epoch 2921
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006564
#
# Epoch 2922
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006563
#
# Epoch 2923
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006562
#
# Epoch 2924
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006561
#
# Epoch 2925
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006560
#
# Epoch 2926
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006559
#
# Epoch 2927
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006558
#
# Epoch 2928
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006557
#
# Epoch 2929
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006556
#
# Epoch 2930
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006555
#
# Epoch 2931
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006554
#
# Epoch 2932
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006553
#
# Epoch 2933
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006552
#
# Epoch 2934
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006551
#
# Epoch 2935
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006550
#
# Epoch 2936
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006549
#
# Epoch 2937
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006548
#
# Epoch 2938
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006547
#
# Epoch 2939
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006546
#
# Epoch 2940
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006545
#
# Epoch 2941
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006544
#
# Epoch 2942
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006543
#
# Epoch 2943
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006542
#
# Epoch 2944
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006541
#
# Epoch 2945
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006540
#
# Epoch 2946
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006539
#
# Epoch 2947
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006538
#
# Epoch 2948
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006537
#
# Epoch 2949
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006536
#
# Epoch 2950
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006535
#
# Epoch 2951
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006534
#
# Epoch 2952
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006533
#
# Epoch 2953
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006532
#
# Epoch 2954
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006531
#
# Epoch 2955
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006530
#
# Epoch 2956
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006529
#
# Epoch 2957
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006528
#
# Epoch 2958
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006527
#
# Epoch 2959
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006526
#
# Epoch 2960
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006525
#
# Epoch 2961
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006524
#
# Epoch 2962
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006523
#
# Epoch 2963
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006522
#
# Epoch 2964
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006522
#
# Epoch 2965
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006521
#
# Epoch 2966
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006520
#
# Epoch 2967
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006519
#
# Epoch 2968
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006518
#
# Epoch 2969
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006517
#
# Epoch 2970
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006516
#
# Epoch 2971
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006515
#
# Epoch 2972
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006514
#
# Epoch 2973
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006513
#
# Epoch 2974
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006512
#
# Epoch 2975
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006511
#
# Epoch 2976
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006510
#
# Epoch 2977
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006509
#
# Epoch 2978
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006508
#
# Epoch 2979
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006507
#
# Epoch 2980
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006506
#
# Epoch 2981
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006505
#
# Epoch 2982
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006504
#
# Epoch 2983
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006503
#
# Epoch 2984
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006502
#
# Epoch 2985
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006502
#
# Epoch 2986
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006501
#
# Epoch 2987
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006500
#
# Epoch 2988
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006499
#
# Epoch 2989
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006498
#
# Epoch 2990
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006497
#
# Epoch 2991
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006496
#
# Epoch 2992
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006495
#
# Epoch 2993
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006494
#
# Epoch 2994
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006493
#
# Epoch 2995
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006492
#
# Epoch 2996
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006491
#
# Epoch 2997
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006490
#
# Epoch 2998
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006489
#
# Epoch 2999
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006488
#
# Epoch 3000
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006488
#
# Done!

# %% [markdown]
# Καθώς περναν οι εποχές μπορουμε να παρατηρήσουμε οτι  το r2_score αυξανεται μεχρι να σταθεροποιηθει ενω το avg loss μειωνεται συνεχως οπως και το loss που κανουμε print ανα 100 epochs
#
# Αν αντικαταστήσουμε την γραμμή torch.manual_seed(50) με torch.manual_seed(100) βλεπουμε πως το r2 δεν καταφερε να αυξηθει οσο με το 50 επισης το loss δεν καταφερε να μειωθει τοσο οσο οταν ειχαμε seed 50
#
# Αν αντικαταστήσουμε τον optimizer από SGD σε Adam βλεπουμε οτι εχουμε πολυ καλυτερα αποτελεσματα και το r2 score καταφερνει να αυξηθει πολυ περισοτερο απο οτι με τον SGD αλλα και το avg loss ειναι πολυ μικροτερο

# %%
from torch.nn.modules.activation import ReLU
# Κώδικας ορισμού του δικτύου
class NeuralNetwork2(nn.Module):
  def __init__(self):
      # Τρέχω την init της κλάσης-γονιού
      super(NeuralNetwork2, self).__init__()
      
      # Δημιουργώ μια μέθοδο Flatten που θα μετατρέπει το Tensor εισόδου σε
      # μονοδιάστατο
      self.flatten = nn.Flatten()

      # Η κλάση Sequential() είναι ένα container μέσα στο οποίο βάζουμε τα
      # Module() που θα χτίζουν τα layers του δικτύου 
      self.network_architecture = nn.Sequential(
          nn.Linear(8,100),
          nn.ReLU(),
          nn.Linear(100,100),
          nn.ReLU(),
          nn.Linear(100,1),
      ) 

  # Η μέθοδος forward απλώς μετατρέπει τα inputs σε διάνυσμα και τα περνάει
  # από τη network_architecture που δημιουργήσαμε
  def forward(self, x):
      x = self.flatten(x)
      logits = self.network_architecture(x)
      return logits

# %% [markdown]
# Η εξοδος του δικτυου μας ειναι γραμμικη συνάρτηση των εισόδων

# %%
# Το manual_seed καθορίζει την τυχαία αρχικοποίηση των βαρών/παραμέτρων του δικτύου
# Πρόκειται απλώς για ένα σταθερό seed στο random number generator της pytorch.
torch.manual_seed(50)
model = NeuralNetwork2()
learning_rate = 0.001
# Ορίζουμε τη Loss Function
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Κώδικας εκπαίδευσης εδώ:

for t in range(3000):
    print(f"Epoch {t+1}\n-------------------------------")
    display = t
    train_loop(train_dataloader, model, loss_fn, optimizer, display)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 2003
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006322
#
# Epoch 2004
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006274
#
# Epoch 2005
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006387
#
# Epoch 2006
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006219
#
# Epoch 2007
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006423
#
# Epoch 2008
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006199
#
# Epoch 2009
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006431
#
# Epoch 2010
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006242
#
# Epoch 2011
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006406
#
# Epoch 2012
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006287
#
# Epoch 2013
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006346
#
# Epoch 2014
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006315
#
# Epoch 2015
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006298
#
# Epoch 2016
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006363
#
# Epoch 2017
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006269
#
# Epoch 2018
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006387
#
# Epoch 2019
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006232
#
# Epoch 2020
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006415
#
# Epoch 2021
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006218
#
# Epoch 2022
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006471
#
# Epoch 2023
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006213
#
# Epoch 2024
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006492
#
# Epoch 2025
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006230
#
# Epoch 2026
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006426
#
# Epoch 2027
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006277
#
# Epoch 2028
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006345
#
# Epoch 2029
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006328
#
# Epoch 2030
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006277
#
# Epoch 2031
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006411
#
# Epoch 2032
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006213
#
# Epoch 2033
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006478
#
# Epoch 2034
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006184
#
# Epoch 2035
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006485
#
# Epoch 2036
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006209
#
# Epoch 2037
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006444
#
# Epoch 2038
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006282
#
# Epoch 2039
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006381
#
# Epoch 2040
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006330
#
# Epoch 2041
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006306
#
# Epoch 2042
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006364
#
# Epoch 2043
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006263
#
# Epoch 2044
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006398
#
# Epoch 2045
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006226
#
# Epoch 2046
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006444
#
# Epoch 2047
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006212
#
# Epoch 2048
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006516
#
# Epoch 2049
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006231
#
# Epoch 2050
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006493
#
# Epoch 2051
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006243
#
# Epoch 2052
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006394
#
# Epoch 2053
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006270
#
# Epoch 2054
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006333
#
# Epoch 2055
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006368
#
# Epoch 2056
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006299
#
# Epoch 2057
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006405
#
# Epoch 2058
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006237
#
# Epoch 2059
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006427
#
# Epoch 2060
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006220
#
# Epoch 2061
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006474
#
# Epoch 2062
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006228
#
# Epoch 2063
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006435
#
# Epoch 2064
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006247
#
# Epoch 2065
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006383
#
# Epoch 2066
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006307
#
# Epoch 2067
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006312
#
# Epoch 2068
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006383
#
# Epoch 2069
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006239
#
# Epoch 2070
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006444
#
# Epoch 2071
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006199
#
# Epoch 2072
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006534
#
# Epoch 2073
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006210
#
# Epoch 2074
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006521
#
# Epoch 2075
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006244
#
# Epoch 2076
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006381
#
# Epoch 2077
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006319
#
# Epoch 2078
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006298
#
# Epoch 2079
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006427
#
# Epoch 2080
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006234
#
# Epoch 2081
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006500
#
# Epoch 2082
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006188
#
# Epoch 2083
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006518
#
# Epoch 2084
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006203
#
# Epoch 2085
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006439
#
# Epoch 2086
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006295
#
# Epoch 2087
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006331
#
# Epoch 2088
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006414
#
# Epoch 2089
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006255
#
# Epoch 2090
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006496
#
# Epoch 2091
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006208
#
# Epoch 2092
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006502
#
# Epoch 2093
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006206
#
# Epoch 2094
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006405
#
# Epoch 2095
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006273
#
# Epoch 2096
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006305
#
# Epoch 2097
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006365
#
# Epoch 2098
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006257
#
# Epoch 2099
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006429
#
# Epoch 2100
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006225
#
# Epoch 2101
# -------------------------------
# loss: 0.002681  [    0/  250]
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006468
#
# Epoch 2102
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006224
#
# Epoch 2103
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006453
#
# Epoch 2104
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006272
#
# Epoch 2105
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006352
#
# Epoch 2106
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006326
#
# Epoch 2107
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006269
#
# Epoch 2108
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006384
#
# Epoch 2109
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006229
#
# Epoch 2110
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006451
#
# Epoch 2111
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006199
#
# Epoch 2112
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006438
#
# Epoch 2113
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006211
#
# Epoch 2114
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006381
#
# Epoch 2115
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006276
#
# Epoch 2116
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006321
#
# Epoch 2117
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006332
#
# Epoch 2118
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006263
#
# Epoch 2119
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006383
#
# Epoch 2120
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006207
#
# Epoch 2121
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006434
#
# Epoch 2122
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006194
#
# Epoch 2123
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006460
#
# Epoch 2124
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006207
#
# Epoch 2125
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006424
#
# Epoch 2126
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006221
#
# Epoch 2127
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006388
#
# Epoch 2128
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006262
#
# Epoch 2129
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006350
#
# Epoch 2130
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006301
#
# Epoch 2131
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006305
#
# Epoch 2132
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006318
#
# Epoch 2133
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006285
#
# Epoch 2134
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006363
#
# Epoch 2135
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006256
#
# Epoch 2136
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006395
#
# Epoch 2137
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006217
#
# Epoch 2138
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006436
#
# Epoch 2139
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006171
#
# Epoch 2140
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006516
#
# Epoch 2141
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006178
#
# Epoch 2142
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006532
#
# Epoch 2143
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006177
#
# Epoch 2144
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006424
#
# Epoch 2145
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006245
#
# Epoch 2146
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006326
#
# Epoch 2147
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006350
#
# Epoch 2148
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006257
#
# Epoch 2149
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006409
#
# Epoch 2150
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006204
#
# Epoch 2151
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006454
#
# Epoch 2152
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006189
#
# Epoch 2153
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006453
#
# Epoch 2154
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006204
#
# Epoch 2155
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006398
#
# Epoch 2156
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006243
#
# Epoch 2157
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006325
#
# Epoch 2158
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006320
#
# Epoch 2159
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006258
#
# Epoch 2160
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006393
#
# Epoch 2161
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006207
#
# Epoch 2162
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006433
#
# Epoch 2163
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006181
#
# Epoch 2164
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006458
#
# Epoch 2165
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006186
#
# Epoch 2166
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006483
#
# Epoch 2167
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006199
#
# Epoch 2168
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006454
#
# Epoch 2169
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006226
#
# Epoch 2170
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006379
#
# Epoch 2171
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006275
#
# Epoch 2172
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006315
#
# Epoch 2173
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006349
#
# Epoch 2174
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006262
#
# Epoch 2175
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006398
#
# Epoch 2176
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006221
#
# Epoch 2177
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006441
#
# Epoch 2178
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006208
#
# Epoch 2179
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006483
#
# Epoch 2180
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006206
#
# Epoch 2181
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006484
#
# Epoch 2182
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006219
#
# Epoch 2183
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006420
#
# Epoch 2184
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006248
#
# Epoch 2185
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006353
#
# Epoch 2186
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006299
#
# Epoch 2187
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006301
#
# Epoch 2188
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006338
#
# Epoch 2189
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006265
#
# Epoch 2190
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006407
#
# Epoch 2191
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006227
#
# Epoch 2192
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006485
#
# Epoch 2193
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006179
#
# Epoch 2194
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006529
#
# Epoch 2195
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006176
#
# Epoch 2196
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006504
#
# Epoch 2197
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006214
#
# Epoch 2198
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006430
#
# Epoch 2199
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006264
#
# Epoch 2200
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006367
#
# Epoch 2201
# -------------------------------
# loss: 0.002578  [    0/  250]
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006319
#
# Epoch 2202
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006320
#
# Epoch 2203
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006347
#
# Epoch 2204
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006298
#
# Epoch 2205
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006392
#
# Epoch 2206
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006267
#
# Epoch 2207
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006400
#
# Epoch 2208
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006239
#
# Epoch 2209
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006442
#
# Epoch 2210
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006233
#
# Epoch 2211
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006467
#
# Epoch 2212
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006224
#
# Epoch 2213
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006452
#
# Epoch 2214
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006250
#
# Epoch 2215
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006442
#
# Epoch 2216
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006287
#
# Epoch 2217
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006398
#
# Epoch 2218
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006296
#
# Epoch 2219
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006346
#
# Epoch 2220
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006317
#
# Epoch 2221
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006330
#
# Epoch 2222
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006355
#
# Epoch 2223
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006327
#
# Epoch 2224
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006388
#
# Epoch 2225
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006281
#
# Epoch 2226
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006443
#
# Epoch 2227
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006229
#
# Epoch 2228
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006537
#
# Epoch 2229
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006198
#
# Epoch 2230
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006626
#
# Epoch 2231
# -------------------------------
# Test Error:
#  r2_scoere: 70.6%, Avg loss: 0.006178
#
# Epoch 2232
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006609
#
# Epoch 2233
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006206
#
# Epoch 2234
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006485
#
# Epoch 2235
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006296
#
# Epoch 2236
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006347
#
# Epoch 2237
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006409
#
# Epoch 2238
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006233
#
# Epoch 2239
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006497
#
# Epoch 2240
# -------------------------------
# Test Error:
#  r2_scoere: 70.5%, Avg loss: 0.006189
#
# Epoch 2241
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006557
#
# Epoch 2242
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006213
#
# Epoch 2243
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006511
#
# Epoch 2244
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006264
#
# Epoch 2245
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006392
#
# Epoch 2246
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006349
#
# Epoch 2247
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006279
#
# Epoch 2248
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006441
#
# Epoch 2249
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006224
#
# Epoch 2250
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006513
#
# Epoch 2251
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006230
#
# Epoch 2252
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006505
#
# Epoch 2253
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006267
#
# Epoch 2254
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006422
#
# Epoch 2255
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006340
#
# Epoch 2256
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006336
#
# Epoch 2257
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006402
#
# Epoch 2258
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006281
#
# Epoch 2259
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006449
#
# Epoch 2260
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006249
#
# Epoch 2261
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006479
#
# Epoch 2262
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006242
#
# Epoch 2263
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006485
#
# Epoch 2264
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006270
#
# Epoch 2265
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006447
#
# Epoch 2266
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006291
#
# Epoch 2267
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006390
#
# Epoch 2268
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006330
#
# Epoch 2269
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006344
#
# Epoch 2270
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006373
#
# Epoch 2271
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006317
#
# Epoch 2272
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006405
#
# Epoch 2273
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006278
#
# Epoch 2274
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006452
#
# Epoch 2275
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006246
#
# Epoch 2276
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006536
#
# Epoch 2277
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006230
#
# Epoch 2278
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2279
# -------------------------------
# Test Error:
#  r2_scoere: 70.4%, Avg loss: 0.006223
#
# Epoch 2280
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006556
#
# Epoch 2281
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006254
#
# Epoch 2282
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006472
#
# Epoch 2283
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006305
#
# Epoch 2284
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006355
#
# Epoch 2285
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006420
#
# Epoch 2286
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006288
#
# Epoch 2287
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006506
#
# Epoch 2288
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006263
#
# Epoch 2289
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006520
#
# Epoch 2290
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006283
#
# Epoch 2291
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006481
#
# Epoch 2292
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006294
#
# Epoch 2293
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006403
#
# Epoch 2294
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006324
#
# Epoch 2295
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006343
#
# Epoch 2296
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006374
#
# Epoch 2297
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006335
#
# Epoch 2298
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006441
#
# Epoch 2299
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006300
#
# Epoch 2300
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006492
#
# Epoch 2301
# -------------------------------
# loss: 0.002512  [    0/  250]
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006251
#
# Epoch 2302
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006541
#
# Epoch 2303
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006238
#
# Epoch 2304
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2305
# -------------------------------
# Test Error:
#  r2_scoere: 70.3%, Avg loss: 0.006239
#
# Epoch 2306
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006550
#
# Epoch 2307
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006273
#
# Epoch 2308
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006463
#
# Epoch 2309
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006353
#
# Epoch 2310
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006374
#
# Epoch 2311
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006435
#
# Epoch 2312
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006303
#
# Epoch 2313
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006479
#
# Epoch 2314
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006268
#
# Epoch 2315
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006528
#
# Epoch 2316
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006270
#
# Epoch 2317
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006513
#
# Epoch 2318
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006271
#
# Epoch 2319
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006488
#
# Epoch 2320
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006303
#
# Epoch 2321
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006448
#
# Epoch 2322
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006354
#
# Epoch 2323
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006415
#
# Epoch 2324
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006397
#
# Epoch 2325
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006375
#
# Epoch 2326
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006404
#
# Epoch 2327
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006341
#
# Epoch 2328
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006432
#
# Epoch 2329
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006310
#
# Epoch 2330
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006487
#
# Epoch 2331
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006273
#
# Epoch 2332
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006574
#
# Epoch 2333
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006257
#
# Epoch 2334
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006620
#
# Epoch 2335
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006257
#
# Epoch 2336
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006563
#
# Epoch 2337
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006313
#
# Epoch 2338
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006457
#
# Epoch 2339
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006397
#
# Epoch 2340
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006338
#
# Epoch 2341
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006481
#
# Epoch 2342
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006283
#
# Epoch 2343
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006556
#
# Epoch 2344
# -------------------------------
# Test Error:
#  r2_scoere: 70.2%, Avg loss: 0.006269
#
# Epoch 2345
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006581
#
# Epoch 2346
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006274
#
# Epoch 2347
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006524
#
# Epoch 2348
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006298
#
# Epoch 2349
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006414
#
# Epoch 2350
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006371
#
# Epoch 2351
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006333
#
# Epoch 2352
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006472
#
# Epoch 2353
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006306
#
# Epoch 2354
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006562
#
# Epoch 2355
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006294
#
# Epoch 2356
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006583
#
# Epoch 2357
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006289
#
# Epoch 2358
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006516
#
# Epoch 2359
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006335
#
# Epoch 2360
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006411
#
# Epoch 2361
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006417
#
# Epoch 2362
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006327
#
# Epoch 2363
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006489
#
# Epoch 2364
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006302
#
# Epoch 2365
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006533
#
# Epoch 2366
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006304
#
# Epoch 2367
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006534
#
# Epoch 2368
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006314
#
# Epoch 2369
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006473
#
# Epoch 2370
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006346
#
# Epoch 2371
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006411
#
# Epoch 2372
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006415
#
# Epoch 2373
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006389
#
# Epoch 2374
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006447
#
# Epoch 2375
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006339
#
# Epoch 2376
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006488
#
# Epoch 2377
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006307
#
# Epoch 2378
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006534
#
# Epoch 2379
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006294
#
# Epoch 2380
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006576
#
# Epoch 2381
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006294
#
# Epoch 2382
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006565
#
# Epoch 2383
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006312
#
# Epoch 2384
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006491
#
# Epoch 2385
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006373
#
# Epoch 2386
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006419
#
# Epoch 2387
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006453
#
# Epoch 2388
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006351
#
# Epoch 2389
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006505
#
# Epoch 2390
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006311
#
# Epoch 2391
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006571
#
# Epoch 2392
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006317
#
# Epoch 2393
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006586
#
# Epoch 2394
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006321
#
# Epoch 2395
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006536
#
# Epoch 2396
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006333
#
# Epoch 2397
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006466
#
# Epoch 2398
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006371
#
# Epoch 2399
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006392
#
# Epoch 2400
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006440
#
# Epoch 2401
# -------------------------------
# loss: 0.002423  [    0/  250]
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006376
#
# Epoch 2402
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006500
#
# Epoch 2403
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006347
#
# Epoch 2404
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006538
#
# Epoch 2405
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006295
#
# Epoch 2406
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006582
#
# Epoch 2407
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006290
#
# Epoch 2408
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006610
#
# Epoch 2409
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006318
#
# Epoch 2410
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006558
#
# Epoch 2411
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006367
#
# Epoch 2412
# -------------------------------
# Test Error:
#  r2_scoere: 69.3%, Avg loss: 0.006453
#
# Epoch 2413
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006422
#
# Epoch 2414
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006387
#
# Epoch 2415
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006488
#
# Epoch 2416
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006356
#
# Epoch 2417
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006561
#
# Epoch 2418
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006322
#
# Epoch 2419
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006587
#
# Epoch 2420
# -------------------------------
# Test Error:
#  r2_scoere: 70.1%, Avg loss: 0.006290
#
# Epoch 2421
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006566
#
# Epoch 2422
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006316
#
# Epoch 2423
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006527
#
# Epoch 2424
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006371
#
# Epoch 2425
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006459
#
# Epoch 2426
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006422
#
# Epoch 2427
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006394
#
# Epoch 2428
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006461
#
# Epoch 2429
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006354
#
# Epoch 2430
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006533
#
# Epoch 2431
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006329
#
# Epoch 2432
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006599
#
# Epoch 2433
# -------------------------------
# Test Error:
#  r2_scoere: 70.0%, Avg loss: 0.006305
#
# Epoch 2434
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006627
#
# Epoch 2435
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006314
#
# Epoch 2436
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006595
#
# Epoch 2437
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006340
#
# Epoch 2438
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006501
#
# Epoch 2439
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006400
#
# Epoch 2440
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006424
#
# Epoch 2441
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006472
#
# Epoch 2442
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006368
#
# Epoch 2443
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006531
#
# Epoch 2444
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006329
#
# Epoch 2445
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006579
#
# Epoch 2446
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006313
#
# Epoch 2447
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006602
#
# Epoch 2448
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006325
#
# Epoch 2449
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006576
#
# Epoch 2450
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006372
#
# Epoch 2451
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006497
#
# Epoch 2452
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006432
#
# Epoch 2453
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006415
#
# Epoch 2454
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006472
#
# Epoch 2455
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006365
#
# Epoch 2456
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006527
#
# Epoch 2457
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006345
#
# Epoch 2458
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006555
#
# Epoch 2459
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006330
#
# Epoch 2460
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006577
#
# Epoch 2461
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006320
#
# Epoch 2462
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006584
#
# Epoch 2463
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006336
#
# Epoch 2464
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006545
#
# Epoch 2465
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006370
#
# Epoch 2466
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006477
#
# Epoch 2467
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006424
#
# Epoch 2468
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006424
#
# Epoch 2469
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006484
#
# Epoch 2470
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006376
#
# Epoch 2471
# -------------------------------
# Test Error:
#  r2_scoere: 68.9%, Avg loss: 0.006528
#
# Epoch 2472
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006338
#
# Epoch 2473
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006559
#
# Epoch 2474
# -------------------------------
# Test Error:
#  r2_scoere: 69.9%, Avg loss: 0.006325
#
# Epoch 2475
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006573
#
# Epoch 2476
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006341
#
# Epoch 2477
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006564
#
# Epoch 2478
# -------------------------------
# Test Error:
#  r2_scoere: 69.7%, Avg loss: 0.006366
#
# Epoch 2479
# -------------------------------
# Test Error:
#  r2_scoere: 69.0%, Avg loss: 0.006500
#
# Epoch 2480
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006396
#
# Epoch 2481
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006429
#
# Epoch 2482
# -------------------------------
# Test Error:
#  r2_scoere: 69.2%, Avg loss: 0.006472
#
# Epoch 2483
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006404
#
# Epoch 2484
# -------------------------------
# Test Error:
#  r2_scoere: 68.8%, Avg loss: 0.006546
#
# Epoch 2485
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006376
#
# Epoch 2486
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006585
#
# Epoch 2487
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006348
#
# Epoch 2488
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006628
#
# Epoch 2489
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006338
#
# Epoch 2490
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006642
#
# Epoch 2491
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006336
#
# Epoch 2492
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2493
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006345
#
# Epoch 2494
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006494
#
# Epoch 2495
# -------------------------------
# Test Error:
#  r2_scoere: 69.5%, Avg loss: 0.006409
#
# Epoch 2496
# -------------------------------
# Test Error:
#  r2_scoere: 69.4%, Avg loss: 0.006433
#
# Epoch 2497
# -------------------------------
# Test Error:
#  r2_scoere: 69.1%, Avg loss: 0.006497
#
# Epoch 2498
# -------------------------------
# Test Error:
#  r2_scoere: 69.6%, Avg loss: 0.006380
#
# Epoch 2499
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006589
#
# Epoch 2500
# -------------------------------
# Test Error:
#  r2_scoere: 69.8%, Avg loss: 0.006344
#
# Epoch 2501
# ...
#
# Epoch 2835
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006652
#
# Epoch 2836
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006718
#
# Epoch 2837
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006634
#
# Epoch 2838
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006757
#
# Epoch 2839
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006607
#
# Epoch 2840
# -------------------------------
# Test Error:
#  r2_scoere: 67.6%, Avg loss: 0.006798
#
# Epoch 2841
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2842
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006852
#
# Epoch 2843
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006576
#
# Epoch 2844
# -------------------------------
# Test Error:
#  r2_scoere: 67.1%, Avg loss: 0.006904
#
# Epoch 2845
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006593
#
# Epoch 2846
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006853
#
# Epoch 2847
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006590
#
# Epoch 2848
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006747
#
# Epoch 2849
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006638
#
# Epoch 2850
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006681
#
# Epoch 2851
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006711
#
# Epoch 2852
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006624
#
# Epoch 2853
# -------------------------------
# Test Error:
#  r2_scoere: 67.7%, Avg loss: 0.006782
#
# Epoch 2854
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006597
#
# Epoch 2855
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006843
#
# Epoch 2856
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006585
#
# Epoch 2857
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006835
#
# Epoch 2858
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006574
#
# Epoch 2859
# -------------------------------
# Test Error:
#  r2_scoere: 67.7%, Avg loss: 0.006790
#
# Epoch 2860
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006598
#
# Epoch 2861
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006731
#
# Epoch 2862
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006646
#
# Epoch 2863
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006685
#
# Epoch 2864
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006713
#
# Epoch 2865
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006651
#
# Epoch 2866
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006762
#
# Epoch 2867
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006623
#
# Epoch 2868
# -------------------------------
# Test Error:
#  r2_scoere: 67.6%, Avg loss: 0.006805
#
# Epoch 2869
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006606
#
# Epoch 2870
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006826
#
# Epoch 2871
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006590
#
# Epoch 2872
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006837
#
# Epoch 2873
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006583
#
# Epoch 2874
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006827
#
# Epoch 2875
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006610
#
# Epoch 2876
# -------------------------------
# Test Error:
#  r2_scoere: 67.7%, Avg loss: 0.006783
#
# Epoch 2877
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006646
#
# Epoch 2878
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006714
#
# Epoch 2879
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006689
#
# Epoch 2880
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006643
#
# Epoch 2881
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006725
#
# Epoch 2882
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006602
#
# Epoch 2883
# -------------------------------
# Test Error:
#  r2_scoere: 67.6%, Avg loss: 0.006805
#
# Epoch 2884
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006596
#
# Epoch 2885
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006860
#
# Epoch 2886
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006594
#
# Epoch 2887
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006844
#
# Epoch 2888
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006596
#
# Epoch 2889
# -------------------------------
# Test Error:
#  r2_scoere: 67.7%, Avg loss: 0.006786
#
# Epoch 2890
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006609
#
# Epoch 2891
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006736
#
# Epoch 2892
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006657
#
# Epoch 2893
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006715
#
# Epoch 2894
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006695
#
# Epoch 2895
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006679
#
# Epoch 2896
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006712
#
# Epoch 2897
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006635
#
# Epoch 2898
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006762
#
# Epoch 2899
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006607
#
# Epoch 2900
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006841
#
# Epoch 2901
# -------------------------------
# loss: 0.002131  [    0/  250]
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006598
#
# Epoch 2902
# -------------------------------
# Test Error:
#  r2_scoere: 67.1%, Avg loss: 0.006914
#
# Epoch 2903
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006612
#
# Epoch 2904
# -------------------------------
# Test Error:
#  r2_scoere: 67.0%, Avg loss: 0.006929
#
# Epoch 2905
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006611
#
# Epoch 2906
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006849
#
# Epoch 2907
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006616
#
# Epoch 2908
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006731
#
# Epoch 2909
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006650
#
# Epoch 2910
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006657
#
# Epoch 2911
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006735
#
# Epoch 2912
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006638
#
# Epoch 2913
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006827
#
# Epoch 2914
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006607
#
# Epoch 2915
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006861
#
# Epoch 2916
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006578
#
# Epoch 2917
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006874
#
# Epoch 2918
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006592
#
# Epoch 2919
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006834
#
# Epoch 2920
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006620
#
# Epoch 2921
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006752
#
# Epoch 2922
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006667
#
# Epoch 2923
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006677
#
# Epoch 2924
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006707
#
# Epoch 2925
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006624
#
# Epoch 2926
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006768
#
# Epoch 2927
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006618
#
# Epoch 2928
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006848
#
# Epoch 2929
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006611
#
# Epoch 2930
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006854
#
# Epoch 2931
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006596
#
# Epoch 2932
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006819
#
# Epoch 2933
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006605
#
# Epoch 2934
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006766
#
# Epoch 2935
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006627
#
# Epoch 2936
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006703
#
# Epoch 2937
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006661
#
# Epoch 2938
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006661
#
# Epoch 2939
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006707
#
# Epoch 2940
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006634
#
# Epoch 2941
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006755
#
# Epoch 2942
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006609
#
# Epoch 2943
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006815
#
# Epoch 2944
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006602
#
# Epoch 2945
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006871
#
# Epoch 2946
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006601
#
# Epoch 2947
# -------------------------------
# Test Error:
#  r2_scoere: 67.2%, Avg loss: 0.006885
#
# Epoch 2948
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006600
#
# Epoch 2949
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006818
#
# Epoch 2950
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006592
#
# Epoch 2951
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006737
#
# Epoch 2952
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006638
#
# Epoch 2953
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006684
#
# Epoch 2954
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006695
#
# Epoch 2955
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006639
#
# Epoch 2956
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006749
#
# Epoch 2957
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006604
#
# Epoch 2958
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006818
#
# Epoch 2959
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006597
#
# Epoch 2960
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006875
#
# Epoch 2961
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006601
#
# Epoch 2962
# -------------------------------
# Test Error:
#  r2_scoere: 67.4%, Avg loss: 0.006852
#
# Epoch 2963
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006588
#
# Epoch 2964
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006758
#
# Epoch 2965
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006603
#
# Epoch 2966
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006682
#
# Epoch 2967
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006662
#
# Epoch 2968
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006652
#
# Epoch 2969
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006707
#
# Epoch 2970
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006613
#
# Epoch 2971
# -------------------------------
# Test Error:
#  r2_scoere: 67.8%, Avg loss: 0.006759
#
# Epoch 2972
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006584
#
# Epoch 2973
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006825
#
# Epoch 2974
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006579
#
# Epoch 2975
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006860
#
# Epoch 2976
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006597
#
# Epoch 2977
# -------------------------------
# Test Error:
#  r2_scoere: 67.5%, Avg loss: 0.006828
#
# Epoch 2978
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006594
#
# Epoch 2979
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006729
#
# Epoch 2980
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006614
#
# Epoch 2981
# -------------------------------
# Test Error:
#  r2_scoere: 68.3%, Avg loss: 0.006667
#
# Epoch 2982
# -------------------------------
# Test Error:
#  r2_scoere: 68.2%, Avg loss: 0.006679
#
# Epoch 2983
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006641
#
# Epoch 2984
# -------------------------------
# Test Error:
#  r2_scoere: 67.9%, Avg loss: 0.006743
#
# Epoch 2985
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006598
#
# Epoch 2986
# -------------------------------
# Test Error:
#  r2_scoere: 67.6%, Avg loss: 0.006810
#
# Epoch 2987
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006580
#
# Epoch 2988
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006877
#
# Epoch 2989
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006588
#
# Epoch 2990
# -------------------------------
# Test Error:
#  r2_scoere: 67.3%, Avg loss: 0.006860
#
# Epoch 2991
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006576
#
# Epoch 2992
# -------------------------------
# Test Error:
#  r2_scoere: 67.7%, Avg loss: 0.006785
#
# Epoch 2993
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006594
#
# Epoch 2994
# -------------------------------
# Test Error:
#  r2_scoere: 68.1%, Avg loss: 0.006693
#
# Epoch 2995
# -------------------------------
# Test Error:
#  r2_scoere: 68.4%, Avg loss: 0.006639
#
# Epoch 2996
# -------------------------------
# Test Error:
#  r2_scoere: 68.5%, Avg loss: 0.006623
#
# Epoch 2997
# -------------------------------
# Test Error:
#  r2_scoere: 68.0%, Avg loss: 0.006711
#
# Epoch 2998
# -------------------------------
# Test Error:
#  r2_scoere: 68.6%, Avg loss: 0.006596
#
# Epoch 2999
# -------------------------------
# Test Error:
#  r2_scoere: 67.6%, Avg loss: 0.006805
#
# Epoch 3000
# -------------------------------
# Test Error:
#  r2_scoere: 68.7%, Avg loss: 0.006581
#
# Done!

# %% [markdown]
# Γενικα αν αλλαξουμε τον sgd σε Adam δεν παρατησουμε μεγαλη διαφορα στην  ταχυτητα αφου ο adam ηταν μολις 2-4 δευτερολεπτα πιο αργος. Ωστωσο στις τιμες βλεπουμε οι με τον adam το r2 αυξανεται παραπανω απο οτι στον sgd αλλα και το avg loss ειναι πιο μικρο
